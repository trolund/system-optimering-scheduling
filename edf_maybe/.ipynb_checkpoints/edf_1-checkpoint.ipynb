# %%
import csv
import math
import heapq
import copy
from dataclasses import dataclass, field
from typing import Any
from itertools import count
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(25, 20), dpi=300)

# %%
# some constants used for indexing
NAME = 0
DURATION = 1
PERIOD = 2
TYPE = 3
PRIORITY = 4
DEADLINE = 5
START_TIME = 6
RESPONSE_TIME = 7 

MT = 10 # microtick

# https://docs.python.org/3/library/heapq.html
# use to only compare deadline for heapq invariant
# use identifer to return elements of same priority in order they were inserted
@dataclass(order=True)
class Task:
    deadline: int
    item: Any=field(compare=False) 
    identifier: int = field(default_factory=count().__next__)

# %%
ts1 = []
ts2 = []
with open('../test_cases/inf_10_10/taskset__1643188013-a_0.1-b_0.1-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv', newline='') as csvfile:
    testreader = csv.DictReader(csvfile, delimiter=';')
    for line in testreader:
        if line['type'] == "TT":
            ts1.append([line['name'], int(line['duration']), int(line['period']), line['type'], int(line['priority']), int(line['deadline'])])
            ts2.append(Task(int(line['deadline']), [line['name'], int(line['duration']), int(line['period']), line['type'], int(line['priority']), int(line['deadline']), None, None]))
            
#heapq.heappush(ts2, task(2000, ['tTT1', 4, 2000, 'TT', 7, 2000]))

print(id(ts2[0]))
# Out:
# 140390137940048

# %%
# sort ready list in increasing order on deadline, calling with 0 will give all
def get_ready(task_set, cycle, ready_list):
    for task in task_set:
        if cycle % task.deadline == 0:
            new_job = copy.deepcopy(task)
            new_job.deadline = new_job.deadline * int(cycle/new_job.deadline) if cycle != 0 else new_job.deadline
            heapq.heappush(ready_list, new_job)
            
    return ready_list

def remove_from_ready(ready_list):
    heapq.heappop(ready_list)

# ts is set of TT tasks
def edf(ts):
    T = math.lcm(2000,3000,4000) # least common multiple of TT task periods
    S = [] # schedule will be hyperperiod long. 12000 microticks == 120 000 microsecs == 120 ms
    ready_list = get_ready(ts, 0, [])
    wcrts = {} # worst case response times
    print(T)

    for cycle in range(1, T*2+2):
        ready_list = get_ready(ts, cycle, ready_list)
        
        if len(ready_list) == 0:
            continue
        else:
            pass
        
        current_job = ready_list[0] # get current job. index 0 always closest deadline using heapq 
        current_job.item[START_TIME] = cycle*MT if current_job.item[START_TIME] == None else current_job.item[START_TIME]
        S.append(current_job)

        # duration given in microticks
        ready_list[0].item[DURATION] = ready_list[0].item[DURATION] - 1
    
        if ready_list[0].item[DURATION] == 0:
            response = cycle * MT - current_job.item[START_TIME] # store in variable to make conditional below more readable
            current_job.item[RESPONSE_TIME] = response
            
            
            # remember worst case response time for each TT
            if current_job.item[NAME] not in wcrts or response > wcrts[current_job.item[NAME]]:
                wcrts[current_job.item[NAME]] = current_job.item[RESPONSE_TIME]

            remove_from_ready(ready_list)

            # why should we update S here ?? to get response there too? 
            S[-1] = current_job
         
    return S, wcrts

# %%
# sum wcrts as  cost??

s, wcrts = edf(ts2)
#print(s)
#len(s)

#print(wcrts)
# Out:
# 12000

# %%
for job in s:
    print("Job: ", job, "\n")
# Out:
# Job:  Task(deadline=2000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 10, 30], identifier=1)
#
# Job:  Task(deadline=2000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 10, 30], identifier=1)
#
# Job:  Task(deadline=2000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 10, 30], identifier=1)
#
# Job:  Task(deadline=2000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 10, 30], identifier=1)
#
# Job:  Task(deadline=2000, item=['tTT6', 0, 2000, 'TT', 7, 2000, 50, 20], identifier=6)
#
# Job:  Task(deadline=2000, item=['tTT6', 0, 2000, 'TT', 7, 2000, 50, 20], identifier=6)
#
# Job:  Task(deadline=2000, item=['tTT6', 0, 2000, 'TT', 7, 2000, 50, 20], identifier=6)
#
# Job:  Task(deadline=2000, item=['tTT8', 0, 2000, 'TT', 7, 2000, 80, 10], identifier=8)
#
# Job:  Task(deadline=2000, item=['tTT8', 0, 2000, 'TT', 7, 2000, 80, 10], identifier=8)
#
# Job:  Task(deadline=2000, item=['tTT9', 0, 2000, 'TT', 7, 2000, 100, 0], identifier=9)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 110, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 220, 20], identifier=15)
#
# Job:  Task(deadline=2000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 220, 20], identifier=15)
#
# Job:  Task(deadline=2000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 220, 20], identifier=15)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 250, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 250, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 250, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 250, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 250, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 250, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT27', 0, 2000, 'TT', 7, 2000, 310, 10], identifier=27)
#
# Job:  Task(deadline=2000, item=['tTT27', 0, 2000, 'TT', 7, 2000, 310, 10], identifier=27)
#
# Job:  Task(deadline=3000, item=['tTT2', 0, 3000, 'TT', 7, 3000, 330, 30], identifier=2)
#
# Job:  Task(deadline=3000, item=['tTT2', 0, 3000, 'TT', 7, 3000, 330, 30], identifier=2)
#
# Job:  Task(deadline=3000, item=['tTT2', 0, 3000, 'TT', 7, 3000, 330, 30], identifier=2)
#
# Job:  Task(deadline=3000, item=['tTT2', 0, 3000, 'TT', 7, 3000, 330, 30], identifier=2)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 370, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 590, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 740, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 740, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 740, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 740, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 740, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 740, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 740, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 740, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 740, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 830, 30], identifier=10)
#
# Job:  Task(deadline=3000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 830, 30], identifier=10)
#
# Job:  Task(deadline=3000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 830, 30], identifier=10)
#
# Job:  Task(deadline=3000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 830, 30], identifier=10)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 870, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 1120, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 1220, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT16', 0, 3000, 'TT', 7, 3000, 1380, 20], identifier=16)
#
# Job:  Task(deadline=3000, item=['tTT16', 0, 3000, 'TT', 7, 3000, 1380, 20], identifier=16)
#
# Job:  Task(deadline=3000, item=['tTT16', 0, 3000, 'TT', 7, 3000, 1380, 20], identifier=16)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 1410, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 1630, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 1930, 40], identifier=25)
#
# Job:  Task(deadline=3000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 1930, 40], identifier=25)
#
# Job:  Task(deadline=3000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 1930, 40], identifier=25)
#
# Job:  Task(deadline=3000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 1930, 40], identifier=25)
#
# Job:  Task(deadline=3000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 1930, 40], identifier=25)
#
# Job:  Task(deadline=4000, item=['tTT0', 0, 4000, 'TT', 7, 4000, 1980, 40], identifier=0)
#
# Job:  Task(deadline=4000, item=['tTT0', 0, 4000, 'TT', 7, 4000, 1980, 40], identifier=0)
#
# Job:  Task(deadline=4000, item=['tTT0', 0, 4000, 'TT', 7, 4000, 1980, 40], identifier=0)
#
# Job:  Task(deadline=4000, item=['tTT0', 0, 4000, 'TT', 7, 4000, 1980, 40], identifier=0)
#
# Job:  Task(deadline=4000, item=['tTT0', 0, 4000, 'TT', 7, 4000, 1980, 40], identifier=0)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT3', 0, 4000, 'TT', 7, 4000, 2030, 120], identifier=3)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT17', 0, 4000, 'TT', 7, 4000, 2160, 330], identifier=17)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT18', 0, 4000, 'TT', 7, 4000, 2500, 120], identifier=18)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT19', 0, 4000, 'TT', 7, 4000, 2630, 150], identifier=19)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT20', 0, 4000, 'TT', 7, 4000, 2790, 100], identifier=20)
#
# Job:  Task(deadline=4000, item=['tTT21', 0, 4000, 'TT', 7, 4000, 2900, 70], identifier=21)
#
# Job:  Task(deadline=4000, item=['tTT21', 0, 4000, 'TT', 7, 4000, 2900, 70], identifier=21)
#
# Job:  Task(deadline=4000, item=['tTT21', 0, 4000, 'TT', 7, 4000, 2900, 70], identifier=21)
#
# Job:  Task(deadline=4000, item=['tTT21', 0, 4000, 'TT', 7, 4000, 2900, 70], identifier=21)
#
# Job:  Task(deadline=4000, item=['tTT21', 0, 4000, 'TT', 7, 4000, 2900, 70], identifier=21)
#
# Job:  Task(deadline=4000, item=['tTT21', 0, 4000, 'TT', 7, 4000, 2900, 70], identifier=21)
#
# Job:  Task(deadline=4000, item=['tTT21', 0, 4000, 'TT', 7, 4000, 2900, 70], identifier=21)
#
# Job:  Task(deadline=4000, item=['tTT21', 0, 4000, 'TT', 7, 4000, 2900, 70], identifier=21)
#
# Job:  Task(deadline=4000, item=['tTT26', 0, 4000, 'TT', 7, 4000, 2980, 0], identifier=26)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT28', 0, 4000, 'TT', 7, 4000, 2990, 180], identifier=28)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=4000, item=['tTT29', 0, 4000, 'TT', 7, 4000, 3180, 120], identifier=29)
#
# Job:  Task(deadline=2000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 20000, 30], identifier=1)
#
# Job:  Task(deadline=2000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 20000, 30], identifier=1)
#
# Job:  Task(deadline=2000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 20000, 30], identifier=1)
#
# Job:  Task(deadline=2000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 20000, 30], identifier=1)
#
# Job:  Task(deadline=2000, item=['tTT6', 0, 2000, 'TT', 7, 2000, 20040, 20], identifier=6)
#
# Job:  Task(deadline=2000, item=['tTT6', 0, 2000, 'TT', 7, 2000, 20040, 20], identifier=6)
#
# Job:  Task(deadline=2000, item=['tTT6', 0, 2000, 'TT', 7, 2000, 20040, 20], identifier=6)
#
# Job:  Task(deadline=2000, item=['tTT8', 0, 2000, 'TT', 7, 2000, 20070, 10], identifier=8)
#
# Job:  Task(deadline=2000, item=['tTT8', 0, 2000, 'TT', 7, 2000, 20070, 10], identifier=8)
#
# Job:  Task(deadline=2000, item=['tTT9', 0, 2000, 'TT', 7, 2000, 20090, 0], identifier=9)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 20100, 100], identifier=14)
#
# Job:  Task(deadline=2000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 20210, 20], identifier=15)
#
# Job:  Task(deadline=2000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 20210, 20], identifier=15)
#
# Job:  Task(deadline=2000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 20210, 20], identifier=15)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 20240, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 20240, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 20240, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 20240, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 20240, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 20240, 50], identifier=22)
#
# Job:  Task(deadline=2000, item=['tTT27', 0, 2000, 'TT', 7, 2000, 20300, 10], identifier=27)
#
# Job:  Task(deadline=2000, item=['tTT27', 0, 2000, 'TT', 7, 2000, 20300, 10], identifier=27)
#
# Job:  Task(deadline=3000, item=['tTT2', 0, 3000, 'TT', 7, 3000, 30000, 30], identifier=2)
#
# Job:  Task(deadline=3000, item=['tTT2', 0, 3000, 'TT', 7, 3000, 30000, 30], identifier=2)
#
# Job:  Task(deadline=3000, item=['tTT2', 0, 3000, 'TT', 7, 3000, 30000, 30], identifier=2)
#
# Job:  Task(deadline=3000, item=['tTT2', 0, 3000, 'TT', 7, 3000, 30000, 30], identifier=2)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT4', 0, 3000, 'TT', 7, 3000, 30040, 210], identifier=4)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 30260, 140], identifier=5)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 30410, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 30410, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 30410, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 30410, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 30410, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 30410, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 30410, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 30410, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 30410, 80], identifier=7)
#
# Job:  Task(deadline=3000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 30500, 30], identifier=10)
#
# Job:  Task(deadline=3000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 30500, 30], identifier=10)
#
# Job:  Task(deadline=3000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 30500, 30], identifier=10)
#
# Job:  Task(deadline=3000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 30500, 30], identifier=10)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 30540, 240], identifier=11)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 30790, 90], identifier=12)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 30890, 150], identifier=13)
#
# Job:  Task(deadline=3000, item=['tTT16', 0, 3000, 'TT', 7, 3000, 31050, 20], identifier=16)
#
# Job:  Task(deadline=3000, item=['tTT16', 0, 3000, 'TT', 7, 3000, 31050, 20], identifier=16)
#
# Job:  Task(deadline=3000, item=['tTT16', 0, 3000, 'TT', 7, 3000, 31050, 20], identifier=16)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 31080, 210], identifier=23)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# Job:  Task(deadline=3000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 31300, 290], identifier=24)
#
# ...
#
# Job:  Task(deadline=21000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 210260, 140], identifier=5)
#
# Job:  Task(deadline=21000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 210260, 140], identifier=5)
#
# Job:  Task(deadline=21000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 210260, 140], identifier=5)
#
# Job:  Task(deadline=21000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 210260, 140], identifier=5)
#
# Job:  Task(deadline=21000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 210260, 140], identifier=5)
#
# Job:  Task(deadline=21000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 210260, 140], identifier=5)
#
# Job:  Task(deadline=21000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 210260, 140], identifier=5)
#
# Job:  Task(deadline=21000, item=['tTT5', 0, 3000, 'TT', 7, 3000, 210260, 140], identifier=5)
#
# Job:  Task(deadline=21000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 210410, 80], identifier=7)
#
# Job:  Task(deadline=21000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 210410, 80], identifier=7)
#
# Job:  Task(deadline=21000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 210410, 80], identifier=7)
#
# Job:  Task(deadline=21000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 210410, 80], identifier=7)
#
# Job:  Task(deadline=21000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 210410, 80], identifier=7)
#
# Job:  Task(deadline=21000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 210410, 80], identifier=7)
#
# Job:  Task(deadline=21000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 210410, 80], identifier=7)
#
# Job:  Task(deadline=21000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 210410, 80], identifier=7)
#
# Job:  Task(deadline=21000, item=['tTT7', 0, 3000, 'TT', 7, 3000, 210410, 80], identifier=7)
#
# Job:  Task(deadline=21000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 210500, 30], identifier=10)
#
# Job:  Task(deadline=21000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 210500, 30], identifier=10)
#
# Job:  Task(deadline=21000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 210500, 30], identifier=10)
#
# Job:  Task(deadline=21000, item=['tTT10', 0, 3000, 'TT', 7, 3000, 210500, 30], identifier=10)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT11', 0, 3000, 'TT', 7, 3000, 210540, 240], identifier=11)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT12', 0, 3000, 'TT', 7, 3000, 210790, 90], identifier=12)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT13', 0, 3000, 'TT', 7, 3000, 210890, 150], identifier=13)
#
# Job:  Task(deadline=21000, item=['tTT16', 0, 3000, 'TT', 7, 3000, 211050, 20], identifier=16)
#
# Job:  Task(deadline=21000, item=['tTT16', 0, 3000, 'TT', 7, 3000, 211050, 20], identifier=16)
#
# Job:  Task(deadline=21000, item=['tTT16', 0, 3000, 'TT', 7, 3000, 211050, 20], identifier=16)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT23', 0, 3000, 'TT', 7, 3000, 211080, 210], identifier=23)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT24', 0, 3000, 'TT', 7, 3000, 211300, 290], identifier=24)
#
# Job:  Task(deadline=21000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 211600, 40], identifier=25)
#
# Job:  Task(deadline=21000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 211600, 40], identifier=25)
#
# Job:  Task(deadline=21000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 211600, 40], identifier=25)
#
# Job:  Task(deadline=21000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 211600, 40], identifier=25)
#
# Job:  Task(deadline=21000, item=['tTT25', 0, 3000, 'TT', 7, 3000, 211600, 40], identifier=25)
#
# Job:  Task(deadline=22000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 220000, 30], identifier=1)
#
# Job:  Task(deadline=22000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 220000, 30], identifier=1)
#
# Job:  Task(deadline=22000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 220000, 30], identifier=1)
#
# Job:  Task(deadline=22000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 220000, 30], identifier=1)
#
# Job:  Task(deadline=22000, item=['tTT6', 0, 2000, 'TT', 7, 2000, 220040, 20], identifier=6)
#
# Job:  Task(deadline=22000, item=['tTT6', 0, 2000, 'TT', 7, 2000, 220040, 20], identifier=6)
#
# Job:  Task(deadline=22000, item=['tTT6', 0, 2000, 'TT', 7, 2000, 220040, 20], identifier=6)
#
# Job:  Task(deadline=22000, item=['tTT8', 0, 2000, 'TT', 7, 2000, 220070, 10], identifier=8)
#
# Job:  Task(deadline=22000, item=['tTT8', 0, 2000, 'TT', 7, 2000, 220070, 10], identifier=8)
#
# Job:  Task(deadline=22000, item=['tTT9', 0, 2000, 'TT', 7, 2000, 220090, 0], identifier=9)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT14', 0, 2000, 'TT', 7, 2000, 220100, 100], identifier=14)
#
# Job:  Task(deadline=22000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 220210, 20], identifier=15)
#
# Job:  Task(deadline=22000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 220210, 20], identifier=15)
#
# Job:  Task(deadline=22000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 220210, 20], identifier=15)
#
# Job:  Task(deadline=22000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 220240, 50], identifier=22)
#
# Job:  Task(deadline=22000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 220240, 50], identifier=22)
#
# Job:  Task(deadline=22000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 220240, 50], identifier=22)
#
# Job:  Task(deadline=22000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 220240, 50], identifier=22)
#
# Job:  Task(deadline=22000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 220240, 50], identifier=22)
#
# Job:  Task(deadline=22000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 220240, 50], identifier=22)
#
# Job:  Task(deadline=22000, item=['tTT27', 0, 2000, 'TT', 7, 2000, 220300, 10], identifier=27)
#
# Job:  Task(deadline=22000, item=['tTT27', 0, 2000, 'TT', 7, 2000, 220300, 10], identifier=27)
#
# Job:  Task(deadline=24000, item=['tTT0', 3, 4000, 'TT', 7, 4000, 240000, None], identifier=0)
#
# Job:  Task(deadline=24000, item=['tTT0', 3, 4000, 'TT', 7, 4000, 240000, None], identifier=0)

# %%
l1 = s[0:int(len(s)/2)]
l2 = s[int(len(s)/2):]

# %%
l1[-1]
# Out:
# Task(deadline=12000, item=['tTT0', 0, 4000, 'TT', 7, 4000, 120000, 40], identifier=0)

# %%
l2[-1]
# Out:
# Task(deadline=24000, item=['tTT0', 3, 4000, 'TT', 7, 4000, 240000, None], identifier=0)

# %%
len(l1)
# Out:
# 1252

# %%
l1[1242]
# Out:
# Task(deadline=10000, item=['tTT15', 0, 2000, 'TT', 7, 2000, 100210, 20], identifier=15)

# %%
l2[1242]
# Out:
# Task(deadline=22000, item=['tTT22', 0, 2000, 'TT', 7, 2000, 220240, 50], identifier=22)

# %%
l1[0]
# Out:
# Task(deadline=2000, item=['tTT1', 0, 2000, 'TT', 7, 2000, 10, 30], identifier=1)

# %%
l2[0]
# Out:
# Task(deadline=12000, item=['tTT0', 0, 4000, 'TT', 7, 4000, 120000, 40], identifier=0)

# %%
len(l1)
# Out:
# 1252

# %%
len(l2)
# Out:
# 1252

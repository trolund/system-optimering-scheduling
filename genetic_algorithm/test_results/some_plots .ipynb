# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# inf_60_10/taskset__1643188539-a_0.6-b_0.1-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv
avgs1 = [3414.679098,3301.504035,3222.349517,3056.940126,2711.955677,2026.669756,1527.504266,1403.545917,1339.635217,1313.025225,1285.645149,1283.426343,1262.727309,1254.029702,1231.693452,1239.025824,1218.751400,1264.484817,1218.297603,1211.062500,1227.806392,1246.041237,1226.282144,1214.823675,1227.109172,1223.843649,1219.642099,1226.172925,1236.736457,1218.247218,1228.936081]

# %%
len(avgs1)
# Out:
# 31

# %%
fig,ax = plt.subplots()
ax.plot(np.arange(0, len(avgs1)), avgs1)
fig.set_size_inches(18.5, 10.5)
plt.title("Average cost vs. generation" + " inf_60_10/taskset__1643188539-a_0.6-b_0.1-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv")
plt.xlabel("Generation number")
plt.ylabel("Average cost of population")
ax.set_xlim(0, len(avgs1))
ax.legend()
fig.set_dpi(300)
#plt.savefig(filename)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# inf_60_10/taskset__1643188539-a_0.6-b_0.1-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv
avgs2 = [3429.634627,3308.507674,3253.338176,3157.675717,2989.345049,2542.456736,1911.753031,1462.880629,1410.460366,1387.863659,1360.681420,1343.677679,1296.240004,1274.523889,1296.412727,1257.257333,1227.637548,1223.081911,1231.400455,1210.828245,1214.403081,1190.671838,1169.651883,1162.824274,1147.738014,1150.295548,1140.047419,1138.946225,1125.674924,1120.532346,1110.416836]

# %%
fig,ax = plt.subplots()
ax.plot(np.arange(0, len(avgs2)), avgs2)
fig.set_size_inches(18.5, 10.5)
plt.title("Average cost vs. generation" + " inf_60_10/taskset__1643188539-a_0.6-b_0.1-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv")
plt.xlabel("Generation number")
plt.ylabel("Average cost of population")
ax.set_xlim(0, len(avgs2))
ax.legend()
fig.set_dpi(300)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#taskset__1643188013-a_0.1-b_0.1-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv
avgs3 = [3666.315789,3464.608251,3226.111181,2757.557617,1833.483573,1097.933686,1001.681401,978.880343,916.611706,869.659124,812.271226,744.923404,687.226609,724.474416,778.557755,734.059727,762.626317,751.801942,753.263736,709.071280,700.116404,591.402252,522.088305,475.104630,445.952452,453.561127,432.657761,439.653882,432.194244,427.797769,452.779278]

# %%
fig,ax = plt.subplots()
ax.plot(np.arange(0, len(avgs3)), avgs3)
fig.set_size_inches(18.5, 10.5)
plt.title("Average cost vs. generation" + " taskset__1643188013-a_0.1-b_0.1-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv")
plt.xlabel("Generation number")
plt.ylabel("Average cost of population")
ax.set_xlim(0, len(avgs3))
ax.legend()
fig.set_dpi(300)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#taskset__1643188013-a_0.1-b_0.1-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv
avgs4 = [3671.777399,3491.849158,3253.176564,2782.445230,1969.354686,1215.295171,946.525262,706.234891,556.428637,493.075886,455.596219,441.330612,474.647912,476.979925,470.151957,447.244859,468.095077,488.597472,463.786971,479.250258,459.461352,499.234182,497.614847,482.610481,475.474176,538.764289,499.604612,487.710247,514.187417,495.367630,521.426048]

# %%
fig,ax = plt.subplots()
ax.plot(np.arange(0, len(avgs4)), avgs4)
fig.set_size_inches(18.5, 10.5)
plt.title("Average cost vs. generation." + " taskset__1643188013-a_0.1-b_0.1-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv")
plt.xlabel("Generation number")
plt.ylabel("Average cost of population")
ax.set_xlim(0, len(avgs4))
ax.legend()
fig.set_dpi(300)
#plt.savefig(avg_costs_taskset__1643188013.pdf)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# taskset__1643188175-a_0.2-b_0.3-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv
avgs5 = [3630.486881,3500.611374,3331.492151,2996.559930,2333.078254,1517.313495,1278.065863,1284.573215,1222.818065,1187.836490,1157.408010,1149.441001,1129.907816,1150.222085,1133.867519,1117.878096,1113.812518,1137.171092,1100.180811,1086.632895,1058.987489,1071.657005,1037.639814,1021.385558,997.969561,981.941323,988.779168,970.552126,959.164929,963.912883,958.632849]
avgs6 = [3630.486881,3500.611374,3331.492151,2996.559930,2333.078254,1517.313495,1278.065863,1284.573215,1222.818065,1187.836490,1157.408010,1149.441001,1129.907816,1150.222085,1133.867519,1117.878096,1113.812518,1137.171092,1100.180811,1086.632895,1058.987489,1071.657005,1037.639814,1021.385558,997.969561,981.941323,988.779168,970.552126,959.164929,963.912883,958.632849]

# %%
#testcases_orig2/inf_20_30/taskset__1643188175-a_0.2-b_0.3-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv
fig,ax = plt.subplots()
ax.plot(np.arange(0, len(avgs5)), avgs5)
fig.set_size_inches(12.5, 8.5)
plt.title("Average cost vs. generation")
plt.xlabel("Generation number")
plt.ylabel("Average cost of population")
ax.set_xlim(0, len(avgs6))
ax.legend()
fig.set_dpi(300)
plt.savefig("avg_costs_taskset__1643188175_smaller1.pdf")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
"taskset__1643188175-a_0.2-b_0.3-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv" == "taskset__1643188175-a_0.2-b_0.3-n_30-m_20-d_unif-p_2000-q_4000-g_1000-t_5__0__tsk.csv"
# Out:
# True

# %%
for i in range(31):
    print(avgs5[i] == avgs6[i])
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
#taskset__1643188157
avgs2 = [3282.219266,3175.721495,3056.859891,2837.477521,2371.956700,1592.111024,1244.787045,1187.643757,1144.579092,1112.927117,1051.601747,1044.505196,1019.547096,998.410442,978.029711,962.401211,935.986393,927.408037,939.332169,892.810869,922.521042,921.029297,928.062740,881.356031,883.118109,885.689564,890.706967,858.885125,870.516473,848.107256,862.366460]

# %%
#avgs2 = [3282.219266,3175.721495,3056.859891,2837.477521,2371.956700,1592.111024,1244.787045,1187.643757,1144.579092,1112.927117,1051.601747,1044.505196,1019.547096,998.410442,978.029711,962.401211,935.986393,927.408037,939.332169,892.810869,922.521042,921.029297,928.062740,881.356031,883.118109,885.689564,890.706967,858.885125,870.516473,848.107256,862.366460]
#avgs2 = [3264.125295,3133.833726,2964.267127,2542.827932,1865.364378,1361.437030,1245.229197,1206.288841,1174.176417,1089.558253,1060.222942,1041.683806,1054.989285,1040.181806,1015.375746,982.475678,949.658608,914.039155,890.777095,852.450306,856.776662,834.264547,816.952959,821.632997,798.342340,804.478285,800.643813,812.781407,799.370854,787.294692,778.676960]
#avgs2 = [3270.566268,3152.866285,3025.798515,2753.125829,2180.637244,1451.229944,1292.994509,1242.865391,1195.576301,1152.118247,1152.801841,1077.370191,1057.263469,1034.077001,1029.977723,985.054835,924.808373,964.092285,935.203549,949.604004,927.097555,941.458109,890.153974,913.411980,893.021761,908.126935,903.109218,884.279214,874.902749,883.301509,852.600503]
#avgs2 = [3263.829138,3161.800155,3039.082879,2762.074412,2227.336039,1566.074385,1266.665656,1199.734375,1169.747605,1104.973485,1051.061146,1032.379044,1044.490216,1021.817079,995.154711,978.146586,957.489341,967.317484,969.204875,946.716990,941.194133,952.445570,950.613235,945.804319,935.259231,932.440669,935.382988,920.551481,892.699440,904.401386,862.323168]
#avgs2 = [3272.426205,3157.283268,3004.246048,2689.149672,2023.624724,1336.323546,1261.632370,1174.724545,1131.987728,1113.060224,1060.656821,986.880159,991.190365,959.978939,992.671838,980.159981,954.191250,960.132859,939.985425,950.173294,939.613862,916.724149,894.398456,874.990373,846.782641,879.264280,849.985914,854.025446,873.658120,857.408498,841.648999]

fig,ax = plt.subplots()
ax.plot(np.arange(0, len(avgs2)), avgs2)
fig.set_size_inches(12.5, 8.5)
plt.title("Average cost vs. generation")
plt.xlabel("Generation number")
plt.ylabel("Average cost of population")
ax.set_xlim(0, len(avgs2))
ax.legend()
fig.set_dpi(300)
plt.savefig("avg_costs_taskset__1643188175_smaller1.pdf")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
